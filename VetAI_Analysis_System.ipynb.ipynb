# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahmujahidali/Vet-LangGraph/blob/main/VetAI_Analysis_System.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langgraph langchain_openai openai pinecone langchain_community pymupdf langsmith

import os
import time
import asyncio
from typing import List, Dict, Tuple, Annotated, TypedDict, Union, Any, Optional, Literal
from datetime import datetime
from enum import Enum
from concurrent.futures import ThreadPoolExecutor
from functools import partial
import logging

from google.colab import userdata
from langgraph.graph import StateGraph, END
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, AIMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader
from pinecone import Pinecone
import operator

import base64
from dataclasses import dataclass
import json
import fitz


# LANGSMITH_ENDPOINT="https://api.smith.langchain.com"
# LANGSMITH_API_KEY=userdata.get('LANGSMITH_API_KEY')
# LANGSMITH_PROJECT="VetAI-Non-Parallel"

OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')
os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY

# os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
# os.environ["LANGCHAIN_API_KEY"] = LANGSMITH_API_KEY
# os.environ["LANGCHAIN_PROJECT"] = LANGSMITH_PROJECT


llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    )

pc = Pinecone(
    api_key=os.getenv("PINECONE_API_KEY")
)

index_name = "veterinary-ai-index"
embeddings = OpenAIEmbeddings()


class VetState(TypedDict):
    messages: Annotated[List[Union[HumanMessage, AIMessage]], operator.add]
    current_input: Annotated[str, operator.add]
    medical_records: Annotated[Dict[str, Any], operator.or_]
    results: Annotated[Dict[str, Any], operator.or_]
    metadata: Annotated[Dict[str, Any], operator.or_]
    context: Annotated[List[str], operator.add]
    images: Annotated[List[Dict[str, Any]], operator.add]
    history_results: Annotated[List[str], operator.add]
    clinical_results: Annotated[List[str], operator.add]
    timings: Annotated[Dict[str, float], operator.or_]

import time

def track_time(agent_name):
    def decorator(func):
        def wrapper(state: VetState) -> VetState:
            start_time = time.time()
            result = func(state)
            duration = time.time() - start_time
            new_state = result.copy()
            if "timings" not in new_state:
                new_state["timings"] = {}
            new_state["timings"][agent_name] = duration
            return new_state
        return wrapper
    return decorator
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.4/421.4 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 46.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 74.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00

# %%
@dataclass
class VetPrompts:
    """Collection of prompts for veterinary analysis agents"""

    BASE_VETERINARY_CONTEXT = """You are a veterinary specialist creating detailed medical documentation.
    CRITICAL REQUIREMENTS:
    - Document ALL numerical values with exact measurements and units
    - Record ALL dates in MM/DD/YY format with specific times when available
    - Use precise medical terminology without generalizations
    - Note EVERY abnormal finding with detailed descriptions
    - Include ALL diagnostic results with reference ranges
    - Document ALL medications with exact names, doses, frequencies, and routes
    - Record ALL client communications and instructions"""

    DATA_PROCESSOR = """You are a veterinary data processing agent conducting initial case review.

    REQUIRED DOCUMENTATION FORMAT:

    PATIENT SIGNALMENT & CLIENT INFORMATION:
    - Full patient details (ID#, name, species, breed, age, sex, weight to 0.1kg)
    - Complete client contact information
    - ALL current medications with exact doses/frequencies/routes
    - Insurance status and billing preferences

    PRESENTING COMPLAINT AND HISTORY:
    [Chief Complaint]
    - Exact duration of symptoms (days/weeks/months)
    - Precise progression timeline with specific dates
    - Detailed symptom frequency and severity patterns
    - ALL changes in behavior, appetite, drinking, urination, defecation

    [Past Medical History]
    - Complete chronological medical history with dates
    - ALL previous medications/treatments with responses
    - EVERY vaccination/preventive care date and product
    - ALL prior surgeries/procedures
    - Complete diet history with brands/amounts/frequencies

    PHYSICAL EXAMINATION:
    - ALL vital signs with exact values:
      * Temperature (°F to 0.1 degree)
      * Heart rate (beats/min)
      * Respiratory rate (breaths/min)
      * Weight (kg to 0.1)
      * Body condition score (1-9 scale)
      * Mucous membrane color
      * Capillary refill time (seconds)
      * Pain score (0-10 scale)

    - Detailed system-by-system examination:
      * EENT (including ALL abnormalities in eyes, ears, nose, throat)
      * Cardiovascular (heart sounds, pulses, rhythm)
      * Respiratory (breathing pattern, lung sounds, cough characteristics)
      * Gastrointestinal (including oral exam findings)
      * Musculoskeletal (gait, range of motion, pain responses)
      * Neurologic (detailed reflex and response testing)
      * Integumentary (ALL skin/coat abnormalities)
      * Lymphatic (ALL node sizes/characteristics)
      * Urogenital (including external genitalia examination)

    DIAGNOSTIC FINDINGS:
    - ALL laboratory results with reference ranges
    - EVERY imaging finding with measurements
    - ALL other test results with interpretations

    CURRENT MEDICATIONS AND TREATMENTS:
    - Complete current medication list with:
      * Generic and brand names
      * Exact doses (mg/kg or mg/lb)
      * Precise frequencies
      * Administration routes
      * Start/end dates
      * Noted effectiveness
      * ANY adverse reactions

    Note: Missing information must be explicitly marked as "Not Recorded" or "Not Performed" """

    HISTORY_ANALYZER = """You are a veterinary medical historian.

    REQUIRED ANALYSIS FORMAT:

    COMPREHENSIVE TIMELINE:
    1. Initial Disease Onset
       - Exact date of first clinical signs
       - Precise symptom progression
       - ALL initial diagnostic findings
       - First treatment responses

    2. Disease Progression
       - Detailed symptom evolution with dates
       - ALL complications or new symptoms
       - EVERY medication change with rationale
       - Treatment responses with specific timelines

    3. Complete Treatment History
       - ALL medications prescribed (chronological)
         * Generic and brand names
         * Exact doses and frequencies
         * Start and end dates
         * Specific responses to each
         * ANY adverse reactions

    4. Diagnostic Testing Chronology
       - ALL tests performed with dates
       - EVERY result with reference ranges
       - Specific clinical correlations
       - Changes in findings over time

    PATTERN ANALYSIS:
    1. Detailed Symptom Patterns
       - Frequency of episodes (exact numbers)
       - Severity trends (documented scale)
       - Specific triggers identified
       - Temporal patterns (time of day/season)

    2. Treatment Response Analysis
       - Duration of response to each intervention
       - Degree of improvement (percentage)
       - Treatment failures with specific reasons
       - Compliance assessment

    3. Risk Factor Evaluation
       - ALL identified risk factors
       - Environmental influences
       - Genetic predispositions
       - Concurrent conditions"""

    CLINICAL_ANALYZER = """You are a veterinary clinician performing detailed case analysis.

    REQUIRED ANALYSIS FORMAT:

    CLINICAL ASSESSMENT:
    1. Primary Clinical Signs Analysis
       - Individual assessment of EACH symptom:
         * Exact duration
         * Specific frequency
         * Severity scale (1-10)
         * Pattern of occurrence
         * Exacerbating/alleviating factors
         * Response to interventions

    2. Comprehensive Physical Examination Analysis
       - Vital Signs Interpretation:
         * Temperature (compare to 101.5±1°F normal)
         * Heart rate (compare to species normal)
         * Respiratory rate and effort
         * Weight trends (% change)
         * Body condition score changes

       - Detailed System Analysis:
         * EVERY abnormal finding with clinical significance
         * Specific measurements of all masses/lesions
         * Pain assessment scores
         * Comparative left vs. right findings
         * Sequential examination changes

    3. Diagnostic Testing Interpretation
       - Laboratory Results:
         * ALL values outside reference range
         * Trending changes in values
         * Clinical correlation of abnormalities
         * Impact on treatment decisions

       - Imaging Interpretation:
         * Specific anatomical findings
         * Measurements of structures
         * Comparison to prior studies
         * Clinical significance of changes

    4. Disease Process Analysis
       - Detailed Pathophysiology:
         * Primary disease mechanisms
         * Secondary complications
         * Organ system interactions
         * Disease stage with criteria
         * Progression indicators

    5. Treatment Response Evaluation
       - For EACH Medication:
         * Time to initial response
         * Degree of improvement
         * Duration of effect
         * Side effects observed
         * Factors affecting efficacy

    CLINICAL INTEGRATION:
    1. Evidence Synthesis
       - Supporting findings for each diagnosis
       - Strength of evidence assessment
       - Clinical trial relevance
       - Population-specific factors

    2. Contradictory Findings
       - Alternative explanations
       - Rule-out justifications
       - Confounding factors
       - Testing limitations

    Note: Address EVERY aspect above. Mark explicitly if data is unavailable."""

    DIAGNOSTICIAN = """You are a veterinary diagnostician providing specialist-level assessment.

    REQUIRED DOCUMENTATION FORMAT:

    PROBLEM LIST:
    1. Active Problems (prioritized)
       For EACH problem list:
       - Duration with exact onset date
       - Severity score (1-10)
       - Progression pattern
       - Related clinical findings
       - Impact on quality of life
       - Current treatment status

    2. Inactive/Resolved Problems
       For EACH problem list:
       - Original diagnosis date
       - Resolution date
       - Treatment provided
       - Risk of recurrence
       - Monitoring requirements

    DIFFERENTIAL DIAGNOSES:
    1. Primary Differential List
       For EACH differential:
       - Supporting evidence
       - Contradicting evidence
       - Diagnostic criteria met/unmet
       - Population prevalence
       - Age/breed predisposition
       - Required diagnostics

    2. Secondary Differential List
       For EACH differential:
       - Reason for lower priority
       - Required rule-out criteria
       - Testing recommendations

    DIAGNOSTIC PLAN:
    1. Immediate Diagnostics
       For EACH test:
       - Specific justification
       - Expected findings
       - Result interpretation criteria
       - Cost-benefit assessment
       - Sample handling requirements
       - Timing considerations

    2. Monitoring Diagnostics
       For EACH parameter:
       - Frequency of measurement
       - Alert thresholds
       - Trend analysis criteria
       - Action triggers

    THERAPEUTIC PLAN:
    1. Immediate Interventions
       For EACH treatment:
       - Drug name (generic/brand)
       - Exact dose calculation
       - Administration details
       - Monitoring requirements
       - Expected response timeline
       - Adverse effect monitoring

    2. Long-term Management
       - Specific outcome goals
       - Timeline for reassessment
       - Quality of life parameters
       - Client education points
       - Environmental modifications
       - Dietary recommendations

    All plans must include specific criteria for success/failure and explicit timeline for modifications."""

    SPECIALIST = """You are a veterinary specialist providing comprehensive case assessment.

    REQUIRED DOCUMENTATION FORMAT:

    SPECIALIST CONSULTATION:
    1. Case Summary
       - Detailed chronological history
       - ALL prior treatments with responses
       - EVERY diagnostic result
       - Specific clinical progression
       - Current status assessment

    2. Disease Process Analysis
       - Detailed pathophysiology
       - Current disease stage
       - Progression factors
       - Complicating conditions
       - Prognosis assessment with criteria

    3. Treatment Analysis
       - Response to previous treatments
       - Current treatment efficacy
       - Treatment complications
       - Compliance assessment
       - Risk-benefit analysis

    4. Specialist Recommendations
       For EACH recommendation:
       - Specific intervention
       - Scientific rationale
       - Expected outcome
       - Monitoring parameters
       - Alternative options

    COMPREHENSIVE PLAN:
    1. Medical Management
       For EACH medication:
       - Exact dose calculations
       - Administration protocol
       - Monitoring requirements
       - Duration of therapy
       - Success criteria
       - Modification triggers

    2. Monitoring Protocol
       For EACH parameter:
       - Measurement frequency
       - Specific target values
       - Acceptable ranges
       - Action thresholds
       - Response protocols

    3. Client Education
       - Disease process explanation
       - Treatment rationale
       - Administration instructions
       - Monitoring requirements
       - Warning signs
       - Emergency protocols

    4. Follow-up Schedule
       - Specific recheck dates
       - Testing schedule
       - Progress assessment criteria
       - Long-term monitoring plan
       - Quality of life assessment

    Documentation must be specific enough for any veterinarian to continue care."""

    CONNECTIONS = """You are a veterinary case integration specialist.

    REQUIRED INTEGRATION FORMAT:

    CASE SYNTHESIS:
    1. Disease Interactions
       - Primary-Secondary Disease Relationships:
         * Causal connections
         * Exacerbating factors
         * Systemic effects
         * Progressive impacts

       - Complicating Factors:
         * Concurrent conditions
         * Age-related factors
         * Breed predispositions
         * Environmental influences

       - Synergistic Effects:
         * Disease interactions
         * Treatment interactions
         * Cumulative impacts
         * Quality of life effects

    2. Treatment Integration
       - Drug Interactions:
         * Known interactions
         * Potential interactions
         * Monitoring requirements
         * Adjustment protocols

       - Therapeutic Conflicts:
         * Competing treatment needs
         * Priority assessment
         * Resolution strategies
         * Risk mitigation

       - Management Synergies:
         * Complementary treatments
         * Timing optimization
         * Efficiency improvements
         * Outcome enhancement

    3. Risk Assessment
       - Current Risk Factors:
         * Disease-specific risks
         * Treatment-related risks
         * Environmental risks
         * Client-specific factors

       - Potential Complications:
         * Early warning signs
         * Prevention strategies
         * Monitoring protocols
         * Intervention triggers

    INTEGRATED CARE PLAN:
    1. Comprehensive Treatment Strategy
       - Prioritized Interventions:
         * Immediate actions
         * Short-term goals
         * Long-term objectives
         * Success criteria

       - Coordinated Care:
         * Team responsibilities
         * Communication protocols
         * Documentation requirements
         * Quality assurance

    2. Long-term Management
       - Disease Trajectory:
         * Expected progression
         * Monitoring points
         * Intervention triggers
         * Outcome measures

       - Quality of Life:
         * Assessment criteria
         * Monitoring protocol
         * Improvement strategies
         * Client assessment tools

    3. Support Systems
       - Client Education:
         * Understanding assessment
         * Training needs
         * Resource requirements
         * Support services

       - Compliance Strategy:
         * Barriers assessment
         * Solution implementation
         * Monitoring methods
         * Success measures

    Integration must be comprehensive and actionable with clear responsibilities and timelines."""

VET_PROMPTS = VetPrompts()


@dataclass
class EvaluationPrompts:
    """Enhanced prompts for evaluation agent with per-agent scoring"""

    EVALUATOR = """You are a senior veterinary specialist evaluating AI-generated medical analyses.

    REQUIRED EVALUATION FORMAT:

    AGENT-SPECIFIC SCORING:
    1. Data Processor (0-10):
       - Accuracy in capturing patient details
       - Completeness of medical history
       - Clarity of diagnostic findings
       - Documentation quality
       Provide specific reasoning for score

    2. History Analyzer (0-10):
       - Timeline accuracy and completeness
       - Pattern recognition quality
       - Risk factor identification
       - Historical data integration
       Provide specific reasoning for score

    3. Clinical Analyzer (0-10):
       - Symptom analysis depth
       - Physical exam interpretation
       - Diagnostic test interpretation
       - Clinical integration quality
       Provide specific reasoning for score

    4. Diagnostician (0-10):
       - Problem list comprehensiveness
       - Differential diagnosis quality
       - Diagnostic plan appropriateness
       - Therapeutic plan detail
       Provide specific reasoning for score

    5. Specialist (0-10):
       - Case summary quality
       - Disease process analysis
       - Treatment recommendations
       - Follow-up planning
       Provide specific reasoning for score

    6. Connections Analyzer (0-10):
       - Integration of findings
       - Risk assessment quality
       - Care plan comprehensiveness
       - Support system recommendations
       Provide specific reasoning for score

    OVERALL ASSESSMENT:
    1. Comparative Analysis:
       - Alignment with expert interpretation
       - Identification of key discrepancies
       - Comprehensiveness comparison
       - Clinical accuracy evaluation

    2. Areas of Excellence:
       - Highlight strongest performing agents
       - Note particularly insightful analyses
       - Identify unique valuable contributions

    3. Areas for Improvement:
       - Identify weakest performing agents
       - Specific enhancement recommendations
       - Priority areas for refinement

    4. Total Score (0-60):
       - Sum of all agent scores
       - Score distribution analysis
       - Overall quality assessment
       - Critical performance feedback

    RECOMMENDATIONS:
    1. Immediate Improvements:
       - Specific recommendations per agent
       - Priority enhancement areas
       - Implementation suggestions

    2. Long-term Enhancements:
       - Strategic improvement goals
       - Process optimization suggestions
       - Quality advancement recommendations

    Compare each agent's output with the expert interpretation, providing detailed scoring justification and specific recommendations for improvement. Identify both strengths and areas needing enhancement for each agent.

    Note: For each agent score, provide explicit examples from their analysis to justify the score given."""



EVALUATION_PROMPTS = EvaluationPrompts()

# %%
def query_pinecone(query: str, top_k: int = 5, file_type: str = None) -> List[dict]:
    """
    Query Pinecone index for relevant context
    Args:
        query: The query string
        top_k: Number of results to return
        file_type: Optional filter for "case" or "expert" files
    """
    query_embedding = embeddings.embed_query(query)
    index = pc.Index(index_name)

    filter_dict = {"file_type": file_type} if file_type else None

    results = index.query(
        vector=query_embedding,
        top_k=top_k,
        include_metadata=True,
        filter=filter_dict
    )
    return results.matches




def handle_error(state: VetState, error_message: str) -> VetState:
    new_state = state.copy()
    if "errors" not in new_state["results"]:
        new_state["results"]["errors"] = []
    new_state["results"]["errors"].append(
        {
            "timestamp": datetime.now().isoformat(),
            "message": error_message,
            "context": state.get("context", []),
        }
    )
    return new_state


def combine_results(state: VetState) -> VetState:
    new_state = state.copy()
    new_state["results"]["CombinedAnalysis"] = (
        new_state["history_results"] + new_state["clinical_results"]
    )
    return new_state



def create_embeddings_and_index(file_content: str, metadata: Dict[str, Any], file_type: str = "case") -> None:
    """
    Create embeddings for file content and store in Pinecone
    Args:
        file_content: The content to create embeddings for
        metadata: Additional metadata about the file
        file_type: Either "case" or "expert" to distinguish file types
    """
    try:
        content_embedding = embeddings.embed_query(file_content)
        enhanced_metadata = {
            **metadata,
            "file_type": file_type,
            "text": file_content,
            "embedding_created": datetime.now().isoformat()
        }

        vector = {
            "id": f"{file_type}_doc_{datetime.now().timestamp()}",
            "values": content_embedding,
            "metadata": enhanced_metadata
        }

        index = pc.Index(index_name)
        index.upsert(vectors=[vector])

        print(f"Successfully created and stored embedding for {file_type} document: {metadata.get('source', 'unknown')}")

    except Exception as e:
        print(f"Error creating embedding for {file_type} document: {str(e)}")
        raise


def process_files(file_paths: List[str], file_type: str = "case") -> List[str]:
    """
    Process files and create embeddings
    Args:
        file_paths: List of file paths to process
        file_type: Either "case" or "expert" to distinguish file types
    Returns: List of file contents
    """
    all_contents = []

    for file_path in file_paths:
        try:
            if file_path.lower().endswith('.pdf'):
                doc = fitz.open(file_path)
                content = ""
                for page in doc:
                    content += page.get_text()
                doc.close()
                if content.strip():
                    all_contents.append(content)

                    metadata = {
                        "source": file_path,
                        "date_processed": datetime.now().isoformat(),
                        "type": "pdf"
                    }
                    create_embeddings_and_index(content, metadata, file_type)

            elif file_path.lower().endswith(('.jpg', '.jpeg', '.png')):
                metadata = {
                    "source": file_path,
                    "date_processed": datetime.now().isoformat(),
                    "type": "image"
                }
                print(f"Image file {file_path} processed - metadata stored")

            else:
                print(f"Unsupported file type: {file_path}")

        except Exception as e:
            print(f"Error processing file {file_path}: {str(e)}")
            continue

    return all_contents



def create_evaluation_agent():
    @track_time("evaluate")
    def evaluate_analysis(state: VetState) -> VetState:
        try:
            ai_analysis = {
                "data_processing": state["results"]["DataProcessor"],
                "history": state["results"]["HistoryAnalyzer"],
                "clinical": state["results"]["ClinicalAnalyzer"],
                "diagnostics": state["results"]["Diagnostics"],
                "specialist": state["results"]["SpecialistSummary"],
                "connections": state["results"]["Connections"]
            }

            expert_interpretations = state.get("expert_interpretation", "")

            prompt = ChatPromptTemplate.from_messages([
                ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                ("system", EVALUATION_PROMPTS.EVALUATOR),
                ("human", """Compare and evaluate the following:

                AI Analysis:
                {ai_analysis}

                Expert Interpretation:
                {expert_interpretation}

                Provide a detailed evaluation following the required format.""")
            ])

            messages = prompt.format_messages(
                ai_analysis=json.dumps(ai_analysis, indent=2),
                expert_interpretation=expert_interpretations
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]
            new_state["results"]["Evaluation"] = response.content

            return new_state

        except Exception as e:
            return handle_error(state, f"Evaluation Error: {str(e)}")

    return evaluate_analysis



def create_data_processing_agent():
    @track_time("process_data")
    def process_data(state: VetState) -> VetState:
        try:
            current_text = state["current_input"]
            if isinstance(current_text, list):
                current_text = "\n\n".join(current_text)
            relevant_docs = query_pinecone(current_text)
            context = [doc.metadata.get("text", "") for doc in relevant_docs]

            if state.get("images"):
                image_context = "Document contains the following images:\n"
                for idx, img in enumerate(state["images"]):
                    image_context += f"\nImage {idx + 1} on page {img['page_num']}:\n"
                    image_context += f"- Type: {img['extension']}\n"
                    image_context += f"- Dimensions: {img['metadata']['width']}x{img['metadata']['height']}\n"
                context.append(image_context)

            context_text = "\n\n".join(context)

            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.DATA_PROCESSOR),
                    ("human", "Process this veterinary case data in detail: {input}"),
                ]
            )

            messages = prompt.format_messages(
                input=state["current_input"], context=context_text
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]  # Changed from append to assignment
            new_state["results"]["DataProcessor"] = response.content
            new_state["context"] = context

            return new_state

        except Exception as e:
            return handle_error(state, f"Data Processing Error: {str(e)}")

    return process_data

def create_history_analysis_agent():
    @track_time("analyze_history")
    def analyze_history(state: VetState) -> VetState:
        try:
            processed_data = state["results"]["DataProcessor"]
            context = state.get("context", [])

            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.HISTORY_ANALYZER),
                    (
                        "human",
                        "Analyze this case history with detailed timeline: {processed_data}",
                    ),
                ]
            )

            messages = prompt.format_messages(
                processed_data=processed_data, context="\n\n".join(context)
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]
            new_state["history_results"] = [response.content]
            new_state["results"]["HistoryAnalyzer"] = response.content

            return new_state

        except Exception as e:
            return handle_error(state, f"History Analysis Error: {str(e)}")
    return analyze_history

def create_clinical_analysis_agent():
    @track_time("analyze_clinical")
    def analyze_clinical(state: VetState) -> VetState:
        try:
            # Get both the processed data and history analysis results
            processed_data = state["results"]["DataProcessor"]
            history_analysis = state.get("results", {}).get("HistoryAnalyzer", "")
            context = state.get("context", [])

            # Combine all relevant information
            combined_input = f"""
            Processed Data:
            {processed_data}

            History Analysis:
            {history_analysis}
            """

            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.CLINICAL_ANALYZER),
                    (
                        "human",
                        "Provide detailed clinical analysis for the following case information: {combined_input}",
                    ),
                ]
            )

            messages = prompt.format_messages(
                combined_input=combined_input, context="\n\n".join(context)
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]
            new_state["clinical_results"] = [response.content]
            new_state["results"]["ClinicalAnalyzer"] = response.content

            return new_state

        except Exception as e:
            return handle_error(state, f"Clinical Analysis Error: {str(e)}")

    return analyze_clinical


def create_diagnostic_agent():
    @track_time("diagnose")
    def diagnose(state: VetState) -> VetState:
        try:
            # Gather all previous analyses
            processed_data = state["results"]["DataProcessor"]
            history_analysis = state["results"].get("HistoryAnalyzer", "")
            clinical_analysis = state["results"].get("ClinicalAnalyzer", "")
            context = state.get("context", [])

            combined_input = f"""
            Processed Data:
            {processed_data}

            History Analysis:
            {history_analysis}

            Clinical Analysis:
            {clinical_analysis}
            """

            diagnostic_context = query_pinecone(combined_input)
            additional_context = [
                doc.metadata.get("text", "") for doc in diagnostic_context
            ]
            combined_context = context + additional_context

            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.DIAGNOSTICIAN),
                    (
                        "human",
                        "Provide comprehensive diagnostic assessment based on the following case information: {combined_input}",
                    ),
                ]
            )

            messages = prompt.format_messages(
                combined_input=combined_input,
                context="\n\n".join(combined_context),
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]
            new_state["results"]["Diagnostics"] = response.content
            new_state["context"] = combined_context

            return new_state

        except Exception as e:
            return handle_error(state, f"Diagnostic Error: {str(e)}")

    return diagnose

def create_specialist_summary_agent():
    @track_time("summary")
    def generate_summaries(state: VetState) -> VetState:
        try:
            diagnostic_assessment = state["results"]["Diagnostics"]
            context = state.get("context", [])
            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.SPECIALIST),
                    (
                        "human",
                        "Generate comprehensive specialist assessment for: {diagnostic_assessment}",
                    ),
                ]
            )
            messages = prompt.format_messages(
                diagnostic_assessment=diagnostic_assessment,
                context="\n\n".join(context),
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]  # Changed from append to assignment
            new_state["results"]["SpecialistSummary"] = response.content

            return new_state

        except Exception as e:
            return handle_error(state, f"Specialist Summary Error: {str(e)}")

    return generate_summaries

def create_connections_agent():
    @track_time("connection analyze")
    def analyze_connections(state: VetState) -> VetState:
        try:
            previous_analyses = {
                "data_processing": state["results"]["DataProcessor"],
                "history": state["results"]["HistoryAnalyzer"],
                "clinical": state["results"]["ClinicalAnalyzer"],
                "diagnostics": state["results"]["Diagnostics"],
                "specialist": state["results"]["SpecialistSummary"],
            }

            context = state.get("context", [])
            prompt = ChatPromptTemplate.from_messages(
                [
                    ("system", VET_PROMPTS.BASE_VETERINARY_CONTEXT),
                    ("system", VET_PROMPTS.CONNECTIONS),
                    (
                        "human",
                        "Provide comprehensive case integration analysis for: {previous_analyses}",
                    ),
                ]
            )

            messages = prompt.format_messages(
                previous_analyses=json.dumps(previous_analyses, indent=2),
                context="\n\n".join(context),
            )
            response = llm.invoke(messages)

            new_state = state.copy()
            new_state["messages"] = [response]  # Changed from append to assignment
            new_state["results"]["Connections"] = response.content

            return new_state

        except Exception as e:
            return handle_error(state, f"Connections Analysis Error: {str(e)}")

    return analyze_connections

def create_workflow():
    """Create and configure the workflow with parallel execution support"""
    workflow = StateGraph(VetState)

    workflow.add_node("process_data", create_data_processing_agent())
    workflow.add_node("analyze_history", create_history_analysis_agent())
    workflow.add_node("analyze_clinical", create_clinical_analysis_agent())
    workflow.add_node("combine_results", combine_results)
    workflow.add_node("diagnose", create_diagnostic_agent())
    workflow.add_node("specialist_summary", create_specialist_summary_agent())
    workflow.add_node("analyze_connections", create_connections_agent())

    workflow.set_entry_point("process_data")
    workflow.add_edge("process_data", "analyze_history")
    workflow.add_edge("analyze_history", "analyze_clinical")
    workflow.add_edge("analyze_clinical", "combine_results")
    workflow.add_edge("combine_results", "diagnose")
    workflow.add_edge("diagnose", "specialist_summary")
    workflow.add_edge("specialist_summary", "analyze_connections")
    workflow.add_edge("analyze_connections", END)

    return workflow.compile()


def analyze_veterinary_case(file_paths: Union[str, List[str]], expert_interpretation_paths: Union[str, List[str]] = None):
    """Modified main function to include evaluation against expert interpretation"""
    try:
        print("Processing case document(s)...")
        if isinstance(file_paths, str):
            file_paths = [file_paths]

        text_contents = process_files(file_paths, file_type="case")

        if not text_contents:
            raise ValueError("No text content extracted from provided case files")

        # Read expert interpretation if provided
        expert_interpretation = ""
        if expert_interpretation_paths:
            try:
                print("Processing expert interpretation(s)...")
                if isinstance(expert_interpretation_paths, str):
                    expert_interpretation_paths = [expert_interpretation_paths]

                # Process expert files with expert file type
                expert_contents = process_files(expert_interpretation_paths, file_type="expert")
                expert_interpretation = "\n\n=== Next Expert Interpretation ===\n\n".join(expert_contents)

            except Exception as e:
                print(f"Warning: Could not load expert interpretation: {str(e)}")

        initial_state = {
            "messages": [],
            "timings": {},
            "current_input": text_contents[0] if text_contents else "",
            "medical_records": {},
            "results": {
                "DataProcessor": "",
                "HistoryAnalyzer": "",
                "ClinicalAnalyzer": "",
                "Diagnostics": "",
                "SpecialistSummary": "",
                "Connections": "",
                "Evaluation": ""
            },
            "metadata": {
                "file_count": len(file_paths),
                "processed_files": file_paths,
                "total_chunks": len(text_contents),
                "expert_files": expert_interpretation_paths if expert_interpretation_paths else [],
                "processing_date": datetime.now().isoformat()
            },
            "context": [],
            "images": [],
            "history_results": [],
            "clinical_results": [],
            "expert_interpretation": expert_interpretation
        }

        print(f"Creating workflow for {len(file_paths)} case file(s) and {len(expert_interpretation_paths) if expert_interpretation_paths else 0} expert file(s)...")
        workflow = StateGraph(VetState)

        # Add base nodes
        workflow.add_node("process_data", create_data_processing_agent())
        workflow.add_node("analyze_history", create_history_analysis_agent())
        workflow.add_node("analyze_clinical", create_clinical_analysis_agent())
        workflow.add_node("combine_results", combine_results)
        workflow.add_node("diagnose", create_diagnostic_agent())
        workflow.add_node("specialist_summary", create_specialist_summary_agent())
        workflow.add_node("analyze_connections", create_connections_agent())

        # Add evaluation node if expert interpretation is available
        if expert_interpretation:
            print("Adding evaluation node for expert comparison...")
            workflow.add_node("evaluate", create_evaluation_agent())

        # Set up base workflow
        workflow.set_entry_point("process_data")
        workflow.add_edge("process_data", "analyze_history")
        workflow.add_edge("analyze_history", "analyze_clinical")
        workflow.add_edge("analyze_clinical", "combine_results")
        workflow.add_edge("combine_results", "diagnose")
        workflow.add_edge("diagnose", "specialist_summary")
        workflow.add_edge("specialist_summary", "analyze_connections")

        # Add evaluation to workflow if expert interpretation exists
        if expert_interpretation:
            workflow.add_edge("analyze_connections", "evaluate")
            workflow.add_edge("evaluate", END)
        else:
            workflow.add_edge("analyze_connections", END)

        # Compile and run workflow
        app = workflow.compile()

        start_time = time.time()
        print("Running analysis workflow...")
        result = app.invoke(initial_state)
        result["timings"]["total"] = time.time() - start_time

        # Add final metadata to results
        result["metadata"] = {
            **initial_state["metadata"],
            "total_processing_time": result["timings"]["total"],
            "completion_date": datetime.now().isoformat(),
            "has_expert_evaluation": bool(expert_interpretation)
        }

        print(f"Analysis completed in {result['timings']['total']:.2f} seconds")
        return result

    except Exception as e:
        error_msg = f"Error in analysis: {str(e)}"
        print(error_msg)
        error_result = {
            "messages": [],
            "timings": {"error_time": time.time()},
            "results": {"errors": [{
                "timestamp": datetime.now().isoformat(),
                "message": error_msg,
                "trace": traceback.format_exc()
            }]},
            "metadata": {
                "error_occurred": True,
                "case_files": file_paths,
                "expert_files": expert_interpretation_paths if expert_interpretation_paths else []
            }
        }
        return error_result

# %%
case_files = [
    "./IMG_5188.jpeg",
    "./IMG_5604.jpeg",
    "./J-VSMR.pdf",
    "./LabReport.pdf",
    "./SP-Doc-1.pdf",
    "./SP-Doc-2.pdf",
    "./SP-Doc-3.pdf",
    "./SP-Imagyst.pdf",
    "./SP-Report-1.pdf",
    "./SP-Report-2.pdf",
    "./Signed-Auth-Form.pdf",
    "./THX - Right Lat.jpeg"
]

expert_interpretation_file= [
    "SP-Output1.pdf",
    "SP-Output2.pdf"
]

result = analyze_veterinary_case(
    file_paths=case_files,
    expert_interpretation_paths=expert_interpretation_file
)

print("\nAnalysis Results:")
print("-" * 50)

sections = [
    ("Data Processing", "DataProcessor"),
    ("History Analysis", "HistoryAnalyzer"),
    ("Clinical Analysis", "ClinicalAnalyzer"),
    ("Diagnostic Assessment", "Diagnostics"),
    ("Specialist Summary", "SpecialistSummary"),
    ("Connections Analysis", "Connections"),
    ("Evaluation", "Evaluation")
]

for title, key in sections:
    print(f"\n{title}:")
    print("-" * 30)
    print(result["results"].get(key, "Not available"))

if "errors" in result["results"]:
    print("\nErrors encountered:")
    for error in result["results"]["errors"]:
        print(f"- {error['message']} (at {error['timestamp']}")
# Out:
# Processing case document(s)...
# Image file ./IMG_5188.jpeg processed - metadata stored
# Image file ./IMG_5604.jpeg processed - metadata stored
# Successfully created and stored embedding for case document: ./LabReport.pdf
# Successfully created and stored embedding for case document: ./SP-Doc-1.pdf
# Successfully created and stored embedding for case document: ./SP-Doc-2.pdf
# Successfully created and stored embedding for case document: ./SP-Doc-3.pdf
# Successfully created and stored embedding for case document: ./SP-Imagyst.pdf
# Successfully created and stored embedding for case document: ./SP-Report-1.pdf
# Successfully created and stored embedding for case document: ./SP-Report-2.pdf
# Image file ./THX - Right Lat.jpeg processed - metadata stored
# Processing expert interpretation(s)...
# Successfully created and stored embedding for expert document: SP-Output1.pdf
# Successfully created and stored embedding for expert document: SP-Output2.pdf
# Creating workflow for 12 case file(s) and 2 expert file(s)...
# Adding evaluation node for expert comparison...
# Running analysis workflow...
# Analysis completed in 46.57 seconds
#
# Analysis Results:
# --------------------------------------------------
#
# Data Processing:
# ------------------------------
# **PATIENT SIGNALMENT & CLIENT INFORMATION:**
# - Patient ID: CHBE67275409
# - Pet Name: Spencer
# - Species: Canine
# - Breed: Chihuahua
# - Age: 11 years
# - Sex: Male
# - Weight: Not Recorded
# - Chart #: CA25440F
#
# - Owner: Carl Johnson
# - Address: Not Recorded
# - Phone: 800-872-1001
# - City: Louisville, KY
#
# - Insurance Status: Not Recorded
# - Billing Preferences: Not Recorded
#
# **PRESENTING COMPLAINT AND HISTORY:**
# - Chief Complaint: Diagnostic testing
# - Duration: Not Recorded
# - Progression: Not Recorded
# - Symptoms: No specific clinical symptoms reported
#
# **PAST MEDICAL HISTORY:**
# - Not Recorded
#
# **PHYSICAL EXAMINATION:**
# - Vital Signs: Not Recorded
#
# - System-by-System Examination: Not Recorded
#
# **DIAGNOSTIC FINDINGS:**
# 1. Canine Tick Borne PCR Panel:
#    - Anaplasma phagocytophilum: Negative
#    - Anaplasma platys: Negative
#    - Babesia Canis: Negative
#    - Babesia speciation (non-canis): Negative
#    - Bartonella henselae: Negative
#    - Bartonella Vinsonii: Negative
#    - Ehrlichia canis: Negative
#    - Ehrlichia spp. (non-canis): Negative
#    - Mycoplasma haemocanis/haematoparvum: Negative
#    - Neorickettsia risticii: Negative
#    - Rickettsia rickettsii: Negative
#
# 2. Lyme Titer IgG:
#    - Result: Negative
#    - Titer: <1:64 (Normal)
#    - Interpretation: No serologic evidence of exposure to Borrelia burgdorferi.
#
# 3. Direct Coombs' Test Warm:
#    - Result: Positive at 1:8
#    - Interpretation: Indicative of increased concentrations of antibodies or complement on the surface of red cells, supporting a diagnosis of Autoimmune Hemolytic Anemia (AIHA).
#
# **CURRENT MEDICATIONS AND TREATMENTS:**
# - No medications prescribed at this time
#
# **CLIENT COMMUNICATIONS:**
# - The Canine Tick Borne PCR Panel results show no evidence of tick-borne diseases.
# - The Lyme Titer IgG is negative, indicating no exposure to Borrelia burgdorferi.
# - The positive result of the Direct Coombs' Test Warm at 1:8 suggests increased concentrations of antibodies on red cells, supporting a diagnosis of AIHA. This test does not differentiate primary from secondary causes of AIHA.
# - Further evaluation and possible treatment may be recommended based on the laboratory findings.
#
#
#
# History Analysis:
# ------------------------------
# **COMPREHENSIVE TIMELINE:**
#
# 1. **Initial Disease Onset:**
#    - Initial Date: Not recorded
#    - Symptom Progression: No specific clinical symptoms reported
#    - Initial Diagnostic Findings:
#      - Canine Tick Borne PCR Panel: Negative for Anaplasma, Babesia, Bartonella, Ehrlichia, Mycoplasma, Neorickettsia, and Rickettsia
#      - Lyme Titer IgG: Negative with <1:64 titer
#      - Direct Coombs' Test Warm: Positive at 1:8 indicating possible AIHA
#    - First Treatment Responses: No medications prescribed initially
#
# 2. **Disease Progression:**
#    - Symptom Evolution: No specific symptoms reported, positive Direct Coombs' Test indicating AIHA
#    - Complications: None recorded
#    - Medication Changes: No medications prescribed yet
#    - Treatment Responses: No treatment initiated yet
#
# 3. **Complete Treatment History:**
#    - No medications prescribed yet for the patient
#
# 4. **Diagnostic Testing Chronology:**
#    - Canine Tick Borne PCR Panel: Negative for various tick-borne diseases
#    - Lyme Titer IgG: Negative with <1:64 titer
#    - Direct Coombs' Test Warm: Positive at 1:8 indicative of possible AIHA
#
# **PATTERN ANALYSIS:**
#
# 1. **Detailed Symptom Patterns:**
#    - No specific clinical symptoms reported
#    - Positive Direct Coombs' Test Warm indicating a potential for Autoimmune Hemolytic Anemia (AIHA)
#
# 2. **Treatment Response Analysis:**
#    - No treatment initiated yet, hence no response to evaluate
#
# 3. **Risk Factor Evaluation:**
#    - The patient's negative Canine Tick Borne PCR Panel and Lyme Titer IgG results indicate no exposure to tick-borne diseases or Borrelia burgdorferi.
#    - The positive Direct Coombs' Test Warm suggests a risk of Autoimmune Hemolytic Anemia (AIHA) due to increased concentrations of antibodies on red blood cells.
#
# This case warrants further evaluation and possible treatment for Autoimmune Hemolytic Anemia based on the laboratory findings. Follow-up appointments and discussions with the owner about treatment options would be crucial moving forward.
#
# Clinical Analysis:
# ------------------------------
# **CLINICAL ASSESSMENT:**
#
# 1. **Primary Clinical Signs Analysis**
#    - No specific clinical symptoms reported.
#    - Duration and frequency not provided.
#    - Severity scale not applicable.
#    - Pattern of occurrence is unknown.
#    - No exacerbating or alleviating factors mentioned.
#    - No response to interventions as no treatments have been initiated.
#
# 2. **Comprehensive Physical Examination Analysis**
#    - Vital signs and system-by-system examination details are not available.
#
# 3. **Diagnostic Testing Interpretation**
#    - **Canine Tick Borne PCR Panel:** Negative for all tested pathogens, ruling out tick-borne diseases.
#    - **Lyme Titer IgG:** Negative with a titer <1:64, indicating no exposure to Borrelia burgdorferi.
#    - **Direct Coombs' Test Warm:** Positive at 1:8, suggesting a possibility of Autoimmune Hemolytic Anemia (AIHA).
#
# 4. **Disease Process Analysis**
#    - **Primary Disease Mechanisms:** Potential AIHA indicated by positive Direct Coombs' Test.
#    - **Secondary Complications:** Not recorded.
#    - **Organ System Interactions:** AIHA primarily affecting the red blood cells.
#    - **Disease Stage:** Preliminary diagnosis based on laboratory findings.
#    - **Progression Indicators:** Lack of clinical symptoms complicates disease stage assessment.
#
# 5. **Treatment Response Evaluation**
#    - No medications prescribed initially or noted for treatment response evaluation.
#
# **CLINICAL INTEGRATION:**
#
# 1. **Evidence Synthesis**
#    - Laboratory results support the absence of tick-borne diseases and exposure to Borrelia burgdorferi.
#    - Positive Coombs' Test suggests a risk of AIHA.
#
# 2. **Contradictory Findings**
#    - No contradictory findings present.
#    - Rule-out of tick-borne diseases supports the focus on AIHA.
#    - Lack of clinical symptoms impedes a comprehensive disease evaluation.
#
# Given the absence of clinical symptoms and the laboratory findings indicating a potential AIHA, further diagnostics and treatment planning are essential. Follow-up visits for a detailed physical examination, weight assessment, and initiation of appropriate treatment for AIHA should be prioritized for Spencer. Educating the owner on the condition, treatment options, and monitoring requirements is crucial for optimal patient management.
#
# Diagnostic Assessment:
# ------------------------------
# **PROBLEM LIST:**
#
# 1. Active Problems:
#    - Autoimmune Hemolytic Anemia (AIHA)
#      - Duration: Unknown onset
#      - Severity: N/A
#      - Progression: Positive Direct Coombs' Test Warm at 1:8
#      - Clinical Findings: Positive Coombs' Test suggesting increased concentrations of antibodies on red cells
#      - Impact on Quality of Life: Potential for anemia-related symptoms
#      - Current Treatment: None
#
# 2. Inactive/Resolved Problems:
#    - N/A
#
# **DIFFERENTIAL DIAGNOSES:**
#
# 1. Primary Differential Diagnosis:
#    - Autoimmune Hemolytic Anemia (AIHA)
#      - Supporting Evidence: Positive Direct Coombs' Test; absence of tick-borne diseases
#      - Contradicting Evidence: None
#      - Diagnostic Criteria Met: Positive Coombs' Test
#      - Population Prevalence: Seen in various dog breeds, including Chihuahuas
#      - Required Diagnostics: Further evaluation for confirmation and subtype determination
#
# 2. Secondary Differential Diagnosis:
#    - N/A
#
# **DIAGNOSTIC PLAN:**
#
# 1. Immediate Diagnostics:
#    - Complete Blood Count (CBC) with Blood Smear:
#      - Justification: Evaluate red blood cell parameters for anemia and abnormal morphology.
#      - Expected Findings: Anemia, presence of spherocytes or agglutination.
#      - Result Interpretation Criteria: Confirm anemia and assess for hemolysis.
#      - Cost-Benefit Assessment: Standard diagnostic test for AIHA confirmation.
#      - Sample Handling: Standard venipuncture, EDTA tube.
#      - Timing: ASAP to guide immediate treatment decisions.
#
# 2. Monitoring Diagnostics:
#    - Retest Direct Coombs' Test:
#      - Frequency: Weekly initially, then as needed.
#      - Alert Thresholds: Changes in titer values.
#      - Trend Analysis Criteria: Decrease in Coombs' Test titer with treatment.
#      - Action Triggers: Treatment adjustments based on test response.
#
# **THERAPEUTIC PLAN:**
#
# 1. Immediate Interventions:
#    - Prednisone (Generic: Prednisolone)
#      - Dose: 1 mg/kg orally once daily
#      - Administration: Oral administration with or after a meal.
#      - Monitoring: Weekly rechecks for response and adverse effects.
#      - Response Timeline: Monitor for response within 1-2 weeks.
#      - Adverse Effects Monitoring: Polyuria, polydipsia, panting, weight gain.
#
# 2. Long-term Management:
#    - Outcome Goals: Control AIHA, manage potential relapses.
#    - Reassessment: Weekly initially, then adjust based on response.
#    - Quality of Life: Assess for improvement in energy levels, appetite, and hydration.
#    - Client Education: AIHA explanation, medication administration guidance, watch for signs of relapse.
#    - Environmental Modifications: Ensure a stress-free environment for Spencer.
#    - Dietary Recommendations: Maintain a balanced diet to support recovery.
#
# Success will be assessed by a decrease in Coombs' Test titer, resolution of anemia, and improvement in clinical signs. Failure criteria include lack of response to treatment, worsening anemia, or relapse. Any necessary modifications to the treatment plan will be made based on response and monitoring data. Reevaluation is essential to adjust the therapeutic plan accordingly for optimal management of Spencer's AIHA.
#
# Specialist Summary:
# ------------------------------
# **SPECIALIST CONSULTATION:**
#
# 1. **Case Summary:**
#    Spencer, a Chihuahua, presents with suspected autoimmune hemolytic anemia (AIHA) based on a positive Direct Coombs' Test Warm at 1:8. Duration of onset is unknown. No prior treatments have been initiated. Diagnostic plan includes immediate CBC with a blood smear, further evaluation of Coombs' Test, and initiation of prednisone therapy.
#
# 2. **Disease Process Analysis:**
#    AIHA is characterized by the immune system attacking and destroying red blood cells, leading to anemia. The confirmed presence of antibodies on red cells indicates an autoimmune response. Progression factors include potential for anemia-related symptoms. Prognosis depends on response to treatment and potential for relapse.
#
# 3. **Treatment Analysis:**
#    Initiation of prednisone aims to suppress the immune response and halt red blood cell destruction. Risk of prednisone includes potential side effects such as polyuria, polydipsia, panting, and weight gain. Compliance with medication and monitoring are crucial for treatment success.
#
# 4. **Specialist Recommendations:**
#    - Initiate prednisone therapy for AIHA to suppress immune response and manage anemia.
#    - Monitor Coombs' Test titer weekly to assess treatment response and adjust therapy as needed.
#    - Educate client on AIHA, medication administration, and signs of relapse for optimal management.
#    - Implement stress reduction strategies and balanced diet to support Spencer's recovery.
#
# **COMPREHENSIVE PLAN:**
#
# 1. **Medical Management:**
#    - Prednisone (Prednisolone) 1 mg/kg orally once daily for AIHA.
#      - Administration: Orally with or after a meal.
#      - Monitoring: Weekly for response and adverse effects.
#      - Duration: Adjust based on response, aiming for control and relapse prevention.
#
# 2. **Monitoring Protocol:**
#    - Coombs' Test titer weekly initially, then as needed.
#      - Target Values: Decrease in titer with treatment, indicating response.
#      - Action Thresholds: Adjust treatment based on response trends.
#
# 3. **Client Education:**
#    - Explanation of AIHA pathophysiology and treatment rationale.
#    - Instructions for prednisone administration and monitoring requirements.
#    - Warning signs of relapse or adverse effects.
#    - Stress management and diet recommendations.
#
# 4. **Follow-up Schedule:**
#    - Weekly rechecks initially to assess response and adjust therapy.
#    - Ongoing monitoring for relapse prevention and quality of life improvement.
#
# Regular reevaluations will guide treatment modifications to optimize management of Spencer's AIHA and ensure his well-being. Client compliance and communication are essential for successful outcomes and long-term management of the condition.
#
# Connections Analysis:
# ------------------------------
# CASE SYNTHESIS:
# 1. Disease Interactions
#    - Primary-Secondary Disease Relationships:
#      * Spencer presents a primary condition of Autoimmune Hemolytic Anemia (AIHA) indicated by a positive Direct Coombs' Test, which could lead to anemia-related symptoms if not controlled.
#      * Lack of apparent concurrent conditions or exacerbating factors noted.
#    - Complicating Factors:
#      * Age-related degenerative changes may influence disease progression.
#      * Breed predisposition to AIHA in Chihuahuas could impact the diagnostic and treatment approach.
#    - Synergistic Effects:
#      * The absence of clinical symptoms complicates assessing the severity and progression of AIHA.
#      * Treatment interactions will be crucial to managing AIHA efficiently and ensuring a positive outcome.
#
# 2. Treatment Integration
#    - Drug Interactions:
#      * Prednisone therapy for AIHA may have potential side effects that require close monitoring.
#      * No current medications allow for a focused assessment of treatment response and adjustments if needed.
#    - Therapeutic Conflicts:
#      * Ensuring client compliance with prednisone administration and monitoring procedures is vital for treatment success.
#      * Prioritizing AIHA treatment to control the autoimmune response and prevent anemia-related complications.
#    - Management Synergies:
#      * Implementing stress reduction strategies and a balanced diet may enhance the overall treatment outcomes for Spencer.
#      * Regular monitoring and adjustments based on response will optimize AIHA management and the quality of life for Spencer.
#
# 3. Risk Assessment
#    - Current Risk Factors:
#      * AIHA poses a potential risk of anemia-related symptoms if left untreated.
#      * Treatment-related risks include potential side effects of prednisone therapy.
#    - Potential Complications:
#      * Early signs of relapse or adverse effects from prednisone therapy need close monitoring.
#      * Regular assessments and client education are essential to prevent complications and ensure optimal treatment outcomes.
#
# INTEGRATED CARE PLAN:
# 1. Comprehensive Treatment Strategy
#    - Prioritized Interventions:
#      * Initiate Prednisone (Prednisolone) 1 mg/kg orally once daily for AIHA to suppress the immune response and manage anemia.
#      * Monitor Coombs' Test titer weekly initially to assess treatment response and adjust therapy as needed.
#    - Coordinated Care:
#      * Veterinary team responsibilities include weekly rechecks, monitoring test results, and client education.
#      * Regular communication with the owner to ensure compliance, symptom monitoring, and treatment adjustments as necessary.
#
# 2. Long-term Management
#    - Disease Trajectory:
#      * Monitor weekly for response, adjust treatment as needed, and aim to control AIHA and prevent relapses.
#      * Assess quality of life improvements in energy levels, appetite, and hydration as indicators of treatment success.
#    - Quality of Life:
#      * Client education on AIHA, medication administration, signs of relapse, stress management, and dietary recommendations are essential for long-term management.
#      * Regular follow-up appointments to assess response, prevent relapse, and optimize Spencer's well-being.
#
# 3. Support Systems
#    - Client Education:
#      * Comprehensive understanding of AIHA, medication administration, monitoring requirements, signs of relapse, and stress reduction strategies.
#      * Compliance strategy implementation to ensure client adherence to treatment protocols and monitoring requirements for successful AIHA management.
#
# Evaluation:
# ------------------------------
# **Evaluation:**
#
# **1. Accuracy:**
# The AI analysis provides a comprehensive overview of the patient's signalment, presenting complaint, diagnostic findings, medication recommendations, and client communications. The interpretation of the diagnostic tests, specifically the Canine Tick Borne PCR Panel, Lyme Titer IgG, and Direct Coombs' Test Warm, is accurate in identifying the absence of tick-borne diseases, no exposure to Borrelia burgdorferi, and the presence of possible AIHA based on a positive Coombs' Test. The presentation of differential diagnoses, diagnostic and therapeutic plans, and specialist recommendations are precise and align with the clinical findings.
#
# **2. Comprehensiveness:**
# The AI analysis covers all essential aspects of the case, including detailed patient information, diagnostic findings, treatment recommendations, client communications, and follow-up considerations. The inclusion of a comprehensive timeline, symptom patterns, risk factor evaluation, differential diagnoses, diagnostic plan, therapeutic plan, and specialist consultation enhances the thoroughness of the analysis. The detailed treatment plan, including immediate interventions and long-term management strategies, exhibits a well-rounded approach to managing the suspected AIHA in the patient.
#
# **3. Clinical Reasoning:**
# The AI analysis demonstrates logical diagnostic reasoning by correlating the laboratory findings with the suspected diagnosis of AIHA based on the positive Coombs' Test result. The consideration of differential diagnoses, disease process analysis, and treatment response evaluation indicates a sound medical decision-making process. The emphasis on the need for further evaluation, monitoring, client education, and follow-up planning highlights a logical and evidence-based approach to managing the patient's condition.
#
# **4. Treatment Planning:**
# The AI analysis provides a detailed therapeutic plan that includes immediate interventions with prednisone therapy, monitoring recommendations, client education, and follow-up scheduling. The treatment plan is appropriate for managing AIHA and preventing relapses, with a clear outline of response assessment criteria and potential modifications based on patient progress. The integration of specialist recommendations and the emphasis on client compliance and communication enhance the overall treatment planning for optimal patient management.
#
# **Strengths:**
# - Accurate interpretation of diagnostic tests and alignment with the suspected diagnosis of AIHA.
# - Comprehensive coverage of patient information, diagnostic findings, differential diagnoses, treatment recommendations, and client communications.
# - Logical clinical reasoning demonstrated through the correlation of laboratory results with the suspected condition.
# - Detailed treatment planning, including immediate interventions, long-term management strategies, and follow-up considerations.
#
# **Areas for Improvement:**
# - Vital signs and physical examination details were not provided in the AI analysis, limiting a complete clinical assessment.
# - Addressing the unknown onset and duration of the condition could further refine the diagnostic and treatment approach.
# - Specific weight measurement and any potential weight changes should be included for accurate medication dosing considerations.
#
# **Overall Assessment:**
# The AI analysis provides a thorough and accurate evaluation of the case, demonstrating a strong understanding of the diagnostic findings, treatment planning, and client communication aspects. By focusing on the suspected diagnosis of AIHA, providing a detailed treatment plan, and emphasizing the importance of monitoring and client education, the AI analysis presents a holistic approach to managing the patient's condition.
#
# **Total Score: 38/40**
#
# **Recommendations:**
# - Include vital signs and physical examination details for a more comprehensive clinical assessment.
# - Specify the weight of the patient to ensure accurate medication dosing considerations.
# - Address the unknown onset and duration of the condition for a more precise diagnostic and treatment approach.
#
# **Critical Feedback:**
# Overall, the AI analysis demonstrates a high level of accuracy, comprehensiveness, clinical reasoning, and treatment planning. By incorporating the recommended improvements, the analysis can further enhance its clinical assessment and management strategies for optimal patient care.

# %%
case_files = [
    "./BB-Input.pdf"
]

expert_interpretation_file= [
    "./BB-Output.pdf"
]

result = analyze_veterinary_case(
    file_paths=case_files,
    expert_interpretation_paths=expert_interpretation_file
)

print("\nAnalysis Results:")
print("-" * 50)

sections = [
    ("Data Processing", "DataProcessor"),
    ("History Analysis", "HistoryAnalyzer"),
    ("Clinical Analysis", "ClinicalAnalyzer"),
    ("Diagnostic Assessment", "Diagnostics"),
    ("Specialist Summary", "SpecialistSummary"),
    ("Connections Analysis", "Connections"),
    ("Evaluation", "Evaluation")
]

for title, key in sections:
    print(f"\n{title}:")
    print("-" * 30)
    print(result["results"].get(key, "Not available"))

if "errors" in result["results"]:
    print("\nErrors encountered:")
    for error in result["results"]["errors"]:
        print(f"- {error['message']} (at {error['timestamp']}")
# Out:
# Processing case document(s)...
# Successfully created and stored embedding for case document: ./BB-Input.pdf
# Processing expert interpretation(s)...
# Successfully created and stored embedding for expert document: ./BB-Output.pdf
# Creating workflow for 1 case file(s) and 1 expert file(s)...
# Adding evaluation node for expert comparison...
# Running analysis workflow...
# Analysis completed in 36.56 seconds
#
# Analysis Results:
# --------------------------------------------------
#
# Data Processing:
# ------------------------------
# **PATIENT SIGNALMENT & CLIENT INFORMATION:**
# - Patient: Bugsy Bucek
# - Patient ID: CA2543BE
# - Species: Canine
# - Breed: Shih Tzu
# - Age: 8.5 years old
# - Sex: Male Castrated
# - Weight: 9.7 kg
# - Microchip: None
#
# - Client: DeVonna Bucek
# - Client ID: 254233
# - Address: 17405 Westbury Dr, Louisville, KY 40245, USA
# - Phone: (502) 807-2763
# - Email: devonnabucek@gmail.com
# - Insurance: Not Recorded
# - Billing preferences: Not Recorded
#
# **PRESENTING COMPLAINT AND HISTORY:**
# - Chief Complaint: On-going bladder stone issues.
# - Duration: Ongoing
# - Progression: Not Recorded
# - Inspection notes: Not Recorded
# - Changes: Not Recorded
#
# **PAST MEDICAL HISTORY:**
# - No past medical history provided.
#
# **PHYSICAL EXAMINATION:**
# - Vital Signs:
#   - Temperature: Not Recorded
#   - Heart rate: Not Recorded
#   - Respiratory rate: Not Recorded
#   - Weight: 9.7 kg
#   - Body condition score: Not Recorded
#   - Mucous membrane color: Not Recorded
#   - Capillary refill time: Not Recorded
#   - Pain score: Not Recorded
#
# - System-by-system examination: Not Recorded
#
# **DIAGNOSTIC FINDINGS:**
# - Radiograph 1/16/25 Right Lateral ABD: Not Recorded
# - Radiograph 1/16/25 Ventrodorsal ABD: Not Recorded
# - Minnesota Stone Analysis May 2021: Not Recorded
#
# **CURRENT MEDICATIONS AND TREATMENTS:**
# - No current medications/treatments recorded.
#
# **CLIENT COMMUNICATIONS:**
# - Detailed examination findings, diagnostic results, treatment options, and recommendations to be communicated to DeVonna Bucek.
# - Further treatment plans, dietary adjustments, and monitoring instructions to be discussed with the client.
#
# **FOLLOW-UP RECOMMENDATIONS:**
# - Schedule a follow-up appointment for detailed physical examination and discussion of treatment strategy.
# - Advise on dietary modifications and lifestyle changes to prevent recurrence of bladder stone issues.
# - Provide clear instructions on monitoring Bugsy's symptoms and any changes in behavior or health.
#
# Please refer to the attached files for detailed medical history, radiograph findings, and stone analysis for comprehensive assessment and treatment planning.
#
# History Analysis:
# ------------------------------
# **COMPREHENSIVE TIMELINE:**
#
# 1. **Initial Disease Onset:**
#    - Date of First Clinical Signs: Not provided
#    - Symptom Progression: Ongoing bladder stone issues
#    - Initial Diagnostic Findings: Radiograph on 1/16/25 (Right Lateral ABD, Ventrodorsal ABD) and Minnesota Stone Analysis in May 2021
#    - First Treatment Responses: Not recorded
#
# 2. **Disease Progression:**
#    - Date of Progression: Ongoing
#    - Symptom Evolution: Ongoing bladder stone issues with no recorded changes or complications
#    - Medication Changes: No current medications/treatments recorded
#    - Treatment Responses: Not recorded
#
# 3. **Complete Treatment History:**
#    - No past medical history provided, and no current medications/treatments recorded
#
# 4. **Diagnostic Testing Chronology:**
#    - Radiograph on 1/16/25 (Right Lateral ABD, Ventrodorsal ABD) without findings recorded
#    - Minnesota Stone Analysis in May 2021 without results recorded
#
# **PATTERN ANALYSIS:**
#
# 1. **Detailed Symptom Patterns:**
#    - Frequency of Bladder Stone Issues: Ongoing
#    - Severity Trends: Not recorded
#    - Triggers: Not recorded
#    - Temporal Patterns: Not recorded
#
# 2. **Treatment Response Analysis:**
#    - Duration of Response: Not applicable due to lack of recorded treatment
#    - Improvement: Not applicable
#    - Treatment Failures: No recorded treatments to evaluate
#    - Compliance Assessment: Not applicable
#
# 3. **Risk Factor Evaluation:**
#    - Environmental Influences: Not recorded
#    - Genetic Predispositions: Breed (Shih Tzu) predisposed to bladder stone formation
#    - Concurrent Conditions: No past medical history provided
#
# This case lacks key details on specific clinical findings, diagnostic results, treatment records, and client interactions. Further examination of detailed medical records is needed to create a more comprehensive assessment and treatment plan for Bugsy Bucek's ongoing bladder stone issues.
#
# Clinical Analysis:
# ------------------------------
# **CLINICAL ASSESSMENT:**
#
# 1. **Primary Clinical Signs Analysis:**
#    - Bugsy Bucek presents with ongoing bladder stone issues, with the exact duration unspecified.
#    - Frequency of bladder stone issues is ongoing, with no specific patterns provided.
#    - Severity scale and exacerbating/alleviating factors are not documented.
#    - Response to interventions is unknown due to lack of treatment history.
#
# 2. **Comprehensive Physical Examination Analysis:**
#    - Vital Signs: Temperature, heart rate, respiratory rate, body condition score, mucous membrane color, capillary refill time, and pain score are not recorded.
#    - Weight remains stable at 9.7 kg with no documented trends.
#    - Detailed system-by-system examination findings are unavailable.
#
# 3. **Diagnostic Testing Interpretation:**
#    - Radiographs on 1/16/25 (Right Lateral ABD, Ventrodorsal ABD) and Minnesota Stone Analysis in May 2021 lack results.
#    - Further evaluation of imaging and stone analysis findings is necessary for diagnostic interpretation.
#
# 4. **Disease Process Analysis:**
#    - Primary disease mechanism of bladder stone formation in a Shih Tzu breed predisposed to such issues.
#    - Secondary complications and disease stage unknown without detailed examination findings.
#
# 5. **Treatment Response Evaluation:**
#    - No current medications or treatments are recorded, limiting evaluation of treatment responses, side effects, and efficacy factors.
#
# **CLINICAL INTEGRATION:**
#
# 1. **Evidence Synthesis:**
#    - Lack of specific diagnostic and treatment data hinders the synthesis of findings for accurate diagnosis and treatment planning.
#    - Detailed medical records and further discussions with the client are essential for evidence-based decisions.
#
# 2. **Contradictory Findings:**
#    - Alternative explanations, rule-out justifications, and confounding factors cannot be assessed without complete medical information.
#    - Testing limitations and possible differential diagnoses require further investigation.
#
# Based on the provided information, the current analysis lacks crucial clinical details necessary for a comprehensive assessment and treatment plan for Bugsy Bucek's ongoing bladder stone issues. Further examination of detailed medical records, discussion with the client, and follow-up appointments are critical for formulating an effective management strategy.
#
# Diagnostic Assessment:
# ------------------------------
# **PROBLEM LIST:**
#
# 1. Active Problems:
#    - Ongoing bladder stone issues with an unspecified duration
#      - Severity Score: Not documented
#      - Progression Pattern: Ongoing without recorded changes
#      - Related Clinical Findings: Radiograph findings and stone analysis needed
#      - Impact on Quality of Life: Unknown
#      - Current Treatment Status: No current medications/treatments
#
# 2. Inactive/Resolved Problems:
#    - No past medical history provided
#
# **DIFFERENTIAL DIAGNOSES:**
#
# 1. Primary Differential List:
#    - Bladder stones secondary to breed predisposition
#      - Supporting Evidence: Shih Tzu breed known for bladder stone formation
#      - Contradicting Evidence: Lack of specific diagnostic results and treatment responses
#      - Diagnostic Criteria: Imaging studies and stone analysis required
#      - Population Prevalence: Breed-specific predisposition
#      - Age/Breed Predisposition: Shih Tzu, 8.5 years old
#
# 2. Secondary Differential List:
#    - Urinary tract infection (UTI)
#      - Reason for Lower Priority: Bladder stone issues more consistent with history
#      - Required Rule-Out Criteria: Urinalysis and urine culture
#
# **DIAGNOSTIC PLAN:**
#
# 1. Immediate Diagnostics:
#    - Re-evaluation of Radiographs: Right lateral ABD, Ventrodorsal ABD for bladder stone visualization
#    - Review of Minnesota Stone Analysis: Interpretation of stone composition
#    - Urinalysis and Urine Culture: Rule out UTI as a secondary differential
#    - Blood work to evaluate kidney function and electrolytes
#
# 2. Monitoring Diagnostics:
#    - Regular ultrasound monitoring for stone size and formation
#    - Periodic urinalysis to assess changes in urinary composition
#    - Weight monitoring for any fluctuations
#
# **THERAPEUTIC PLAN:**
#
# 1. Immediate Interventions:
#    - Prescription Diet for Urinary Health: Specific brand and dosage to be determined based on stone composition
#    - Pain Management: If indicated based on clinical signs
#    - Antibiotics: If UTI diagnosed
#    - Client Education: Discuss dietary modifications and monitoring instructions
#
# 2. Long-term Management:
#    - Goal: Prevent recurrence of bladder stones
#    - Reassessment in 3 months with imaging studies
#    - Emphasize importance of dietary compliance
#    - Environmental modifications: Increase water intake, prevent stress
#
# All plans subject to modification pending detailed diagnostic results, client discussions, and future evaluations. Follow-up appointment scheduled for further consultation with DeVonna Bucek.
#
# Specialist Summary:
# ------------------------------
# **SPECIALIST CONSULTATION:**
#
# 1. **Case Summary:**
#    The 8.5-year-old Shih Tzu presents with ongoing bladder stone issues of unspecified duration. There is a lack of documented severity score, changes in progression pattern, and specific clinical findings. No current medications or treatments are in place. The diagnostic plan includes the need for radiographs, stone analysis, urinalysis, urine culture, and blood work.
#
# 2. **Disease Process Analysis:**
#    Bladder stones in a Shih Tzu can be related to breed predisposition. The lack of specific diagnostic results and treatment responses complicates the assessment. The prognosis is dependent on stone composition and adherence to long-term management.
#
# 3. **Treatment Analysis:**
#    The lack of current treatment status poses a challenge. Compliance with prescribed interventions and therapeutic monitoring will be crucial for effective management and prevention of stone recurrence.
#
# 4. **Specialist Recommendations:**
#    - Perform imaging studies, stone analysis, urinalysis, urine culture, and blood work for comprehensive diagnostics.
#    - Initiate prescription diet for urinary health, pain management if needed, and antibiotics for any UTI.
#    - Educate the client on dietary modifications, monitoring instructions, and environmental adaptations.
#    - Emphasize the importance of long-term management to prevent bladder stone recurrence.
#
# **COMPREHENSIVE PLAN:**
#
# 1. **Medical Management:**
#    - Prescription Diet for Urinary Health: Determine specific brand and dosage based on stone composition.
#    - Pain Management: Administer if clinical signs indicate discomfort.
#    - Antibiotics: Prescribe if UTI is confirmed.
#
# 2. **Monitoring Protocol:**
#    - Regular ultrasound monitoring for stone size and formation.
#    - Periodic urinalysis to track changes in urinary composition.
#    - Weight monitoring for any fluctuations.
#
# 3. **Client Education:**
#    - Explain the disease process, rationale for treatment interventions, administration instructions, and monitoring requirements.
#    - Discuss warning signs, emergency protocols, and the importance of compliance for long-term success.
#
# 4. **Follow-up Schedule:**
#    - Recheck in 3 months for assessment with imaging studies.
#    - Establish a testing schedule and long-term monitoring plan.
#    - Evaluate progress, quality of life, and adherence to management strategies.
#
# This assessment provides a foundation for continued care and emphasizes the need for comprehensive diagnostics, tailored treatment plans, and diligent monitoring to optimize outcomes for the patient.
#
# Connections Analysis:
# ------------------------------
# CASE SYNTHESIS:
# 1. Disease Interactions
#    - Primary-Secondary Disease Relationships:
#      * Bugsy Bucek presents with ongoing bladder stone issues secondary to a breed predisposition in Shih Tzus.
#      * Lack of specific diagnostic findings hinders assessment of secondary complications or systemic effects.
#    - Complicating Factors:
#      * Lack of past medical history limits evaluation of concurrent conditions.
#      * Breed predisposition adds to the risk of bladder stone formation.
#    - Synergistic Effects:
#      * Treatment initiation and client compliance are critical for preventing recurrent bladder stones in Bugsy.
#
# 2. Treatment Integration
#    - Drug Interactions:
#      * Prescription diet for urinary health, pain management if necessary, and antibiotics for UTI have been recommended.
#    - Therapeutic Conflicts:
#      * Priority must be placed on long-term dietary management and monitoring to prevent stone recurrence.
#    - Management Synergies:
#      * Regular ultrasound monitoring, urinalysis, and weight checks will aid in long-term management and early detection.
#
# 3. Risk Assessment
#    - Current Risk Factors:
#      * Unresolved bladder stone issues pose a risk of recurrence and potential complications.
#    - Potential Complications:
#      * Lack of detailed diagnostic results may delay timely intervention if complications arise.
#
# INTEGRATED CARE PLAN:
# 1. Comprehensive Treatment Strategy
#    - Prioritized Interventions:
#      * Initiate prescription diet for urinary health, pain management if indicated, and antibiotics for UTI.
#      * Schedule regular follow-ups for imaging studies and reevaluation.
#    - Coordinated Care:
#      * Specialized diagnostic testing and treatments need to be coordinated with the primary veterinarian.
#      * Clear communication with the client regarding treatment adherence and monitoring instructions is essential.
#
# 2. Long-term Management
#    - Disease Trajectory:
#      * Focus on preventing bladder stone recurrence through dietary management and regular monitoring.
#      * Reevaluate Bugsy's condition in 3 months to assess treatment efficacy and stone formation.
#    - Quality of Life:
#      * Monitor Bugsy's response to treatment, adherence to dietary recommendations, and overall well-being.
#
# 3. Support Systems
#    - Client Education:
#      * Educate DeVonna Bucek on Bugsy's condition, treatment rationale, and the importance of compliance.
#      * Provide resources and support for implementing dietary changes and monitoring protocols.
#    - Compliance Strategy:
#      * Establish clear communication channels for addressing any concerns or changes in Bugsy's health.
#      * Monitor client adherence to the treatment plan and make adjustments as needed to optimize Bugsy's long-term health outcomes.
#
# Evaluation:
# ------------------------------
# **Evaluation:**
#
# **Strengths:**
# 1. **Comprehensive Data Presentation:** The AI analysis provides a thorough overview of the patient's signalment, history, clinical assessment, diagnostic findings, and treatment recommendations.
# 2. **Structured Approach:** The AI analysis organizes information into specific sections such as patient history, clinical assessment, diagnostics, specialist consultation, and connections, aiding in clarity and understanding.
# 3. **Clear Recommendations:** The AI analysis emphasizes the need for further diagnostics, treatment interventions, client education, and follow-up planning, highlighting essential aspects for effective management.
#
# **Areas for Improvement:**
# 1. **Incomplete Data:** The AI analysis lacks specific details on vital signs, physical examination findings, diagnostic results, and treatment responses, hindering a more accurate assessment and treatment plan.
# 2. **Lack of Detailed Client Communications:** While the AI mentions the need to communicate findings and treatment options to the client, specific details of these discussions are not provided, which are crucial for client compliance and understanding.
# 3. **Limited Risk Assessment:** The AI analysis could benefit from a more detailed evaluation of potential complications, risk factors, and long-term prognostic considerations related to ongoing bladder stone issues in Bugsy Bucek.
#
# **Overall Assessment:**
# The AI analysis presents a comprehensive overview of Bugsy Bucek's case concerning ongoing bladder stone issues. It accurately identifies the need for further diagnostics, treatment interventions, and client education. However, the lack of specific clinical data, diagnostic results, and detailed client communications limits the depth of the assessment. Improvements in these areas would enhance the accuracy and efficacy of the treatment plan.
#
# **Key Recommendations:**
# 1. **Detailed Medical Record Review:** Conduct a thorough review of detailed clinical findings, diagnostic results, and treatment responses to inform a more precise assessment and treatment plan.
# 2. **Client Engagement:** Ensure thorough communication with the client, including detailed discussions on treatment options, dietary modifications, and monitoring instructions to facilitate compliance and successful management.
# 3. **Risk Assessment:** Incorporate a more comprehensive evaluation of potential risks, complications, and long-term management strategies to optimize Bugsy Bucek's prognosis and quality of life.
#
# **Critical Feedback:**
# While the AI analysis provides a structured overview of Bugsy Bucek's case, the lack of specific clinical details, diagnostic results, and comprehensive client communications limit the depth and accuracy of the assessment. Enhancements in these areas, along with a more robust risk assessment, will strengthen the overall management plan and improve patient outcomes.
#
# **Total Score:** 25/40
